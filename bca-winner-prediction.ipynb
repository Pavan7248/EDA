# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ipl-data-set/matches.csv
# /kaggle/input/ipl-data-set/teamwise_home_and_away.csv
# /kaggle/input/ipl-data-set/deliveries.csv
# /kaggle/input/ipl-data-set/most_runs_average_strikerate.csv
# /kaggle/input/ipl-data-set/teams.csv
# /kaggle/input/ipl-data-set/Players.xlsx

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression

# %%
deliveries = pd.read_csv('/kaggle/input/ipl-data-set/deliveries.csv')
matches = pd.read_csv('/kaggle/input/ipl-data-set/matches.csv')

# %%
deliveries.sample(4)
# Out:
#         match_id  inning                 batting_team  \
# 169211     11310       1               Mumbai Indians
# 82510        350       1  Royal Challengers Bangalore
# 142489       603       1          Sunrisers Hyderabad
# 33715        145       1             Rajasthan Royals
#
#                        bowling_team  over  ball       batsman non_striker  \
# 169211          Sunrisers Hyderabad     8     5  Ishan Kishan   Q de Kock
# 82510               Kings XI Punjab     6     4      CH Gayle     V Kohli
# 142489  Royal Challengers Bangalore     2     3     DA Warner    S Dhawan
# 33715               Kings XI Punjab     8     1      GC Smith     NV Ojha
#
#                bowler  is_super_over  ...  bye_runs  legbye_runs  noball_runs  \
# 169211  Mohammad Nabi              0  ...         0            0            0
# 82510         P Awana              0  ...         0            0            0
# 142489      SR Watson              0  ...         0            0            0
# 33715    Yuvraj Singh              0  ...         0            0            0
#
#         penalty_runs  batsman_runs  extra_runs  total_runs  player_dismissed  \
# 169211             0             0           0           0               NaN
# 82510              0             1           0           1               NaN
# 142489             0             2           0           2               NaN
# 33715              0             1           0           1               NaN
#
#        dismissal_kind fielder
# 169211            NaN     NaN
# 82510             NaN     NaN
# 142489            NaN     NaN
# 33715             NaN     NaN
#
# [4 rows x 21 columns]

# %%
matches.sample(4)
# Out:
#         id    Season           city        date                   team1  \
# 523    524  IPL-2015         Mumbai  12-04-2015         Kings XI Punjab
# 55      56  IPL-2017         Mumbai  16-05-2017  Rising Pune Supergiant
# 727  11323  IPL-2019         Mohali  16-04-2019         Kings XI Punjab
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019     Sunrisers Hyderabad
#
#                 team2       toss_winner toss_decision  result  dl_applied  \
# 523    Mumbai Indians    Mumbai Indians         field  normal           0
# 55     Mumbai Indians    Mumbai Indians         field  normal           0
# 727  Rajasthan Royals  Rajasthan Royals         field  normal           0
# 753    Delhi Capitals    Delhi Capitals         field  normal           0
#
#                      winner  win_by_runs  win_by_wickets    player_of_match  \
# 523         Kings XI Punjab           18               0          GJ Bailey
# 55   Rising Pune Supergiant           20               0  Washington Sundar
# 727         Kings XI Punjab           12               0           R Ashwin
# 753          Delhi Capitals            0               2            RR Pant
#
#                  venue         umpire1          umpire2 umpire3
# 523   Wankhede Stadium    AK Chaudhary     K Srinivasan     NaN
# 55    Wankhede Stadium          S Ravi    C Shamshuddin     NaN
# 727  IS Bindra Stadium  Anil Chaudhary  Vineet Kulkarni  S Ravi
# 753   ACA-VDCA Stadium             NaN              NaN     NaN
